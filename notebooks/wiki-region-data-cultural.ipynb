# %% [markdown]
# # Article -> Country (Cultural)
# This notebook computes what countries are associated with each Wikipedia article based on various cultural properties on Wikidata. It complements a notebook that computes countries via geolocation of the latitude-longitude coordinates extracted from Wikidata.

# %%
import csv
import json
import os
import sys

import requests

import wmfdata

# %%
spark = wmfdata.spark.create_session(app_name='pyspark reg; regions; isaacj',
                                  type='yarn-regular', # local, yarn-regular, yarn-large
                                  )
# Out:
# SPARK_HOME: /usr/lib/spark3
# Using Hadoop client lib jars at 3.2.0, provided by Spark.
# PYSPARK_PYTHON=/opt/conda-analytics/bin/python3
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/04/26 15:11:11 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in mesos/standalone/kubernetes and LOCAL_DIRS in YARN).
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12000. Attempting port 12001.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12001. Attempting port 12002.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12002. Attempting port 12003.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12003. Attempting port 12004.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12004. Attempting port 12005.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12005. Attempting port 12006.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12006. Attempting port 12007.
# 24/04/26 15:11:11 WARN Utils: Service 'sparkDriver' could not bind on port 12007. Attempting port 12008.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4045. Attempting port 4046.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4046. Attempting port 4047.
# 24/04/26 15:11:12 WARN Utils: Service 'SparkUI' could not bind on port 4047. Attempting port 4048.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13000. Attempting port 13001.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13001. Attempting port 13002.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13002. Attempting port 13003.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13003. Attempting port 13004.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13004. Attempting port 13005.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13005. Attempting port 13006.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13006. Attempting port 13007.
# 24/04/26 15:11:21 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 13007. Attempting port 13008.

# %% [markdown]
# ## Load in supporting data files from Github

# %%
QID_TO_REGION = {}
COUNTRY_PROPERTIES = {
    "P17": "country",
    "P19": "place of birth",
    "P27": "country of citizenship",
    "P131": "located in the administrative territorial entity",
    "P183": "endemic to",
    "P361": "part of",
    "P495": "country of origin",
    "P1269": "facet of",
    "P1532": "country for sport",
    "P3842": "located in present-day administrative territorial entity",
    }

# %%
data_dir = './data'
aggregation_tsv = os.path.join(data_dir, 'country_aggregation.tsv')
aggregation_url = "https://github.com/geohci/wiki-region-groundtruth/raw/main/resources/country_aggregation.tsv"
aggregation_header = ['Aggregation', 'From', 'QID To', 'QID From']
agg_qid_to_idx = aggregation_header.index("QID To")
agg_qid_from_idx = aggregation_header.index("QID From")

countries_tsv = os.path.join(data_dir, "countries.tsv")
countries_url = "https://raw.githubusercontent.com/wikimedia-research/canonical-data/master/country/countries.tsv"
countries_header = ['name', 'iso_code', 'iso_alpha3_code', 'wikidata_id', 'is_protected', 'data_risk_score', 'data_risk_classification',
                    'maxmind_continent', 'un_continent', 'un_subcontinent', 'un_m49_code', 'wikimedia_region', 'grant_committee_region',
                    'form_990_region', 'economic_region', 'emerging_classification', 'is_eu', 'is_un_member', 'is_un_data_entity',
                    'is_imf_data_entity', 'is_world_bank_data_entity', 'is_penn_world_table_data_entity', 'market_research_classification']
country_qid_idx = countries_header.index("wikidata_id")
country_name_idx = countries_header.index("name")

# %%
if not os.path.exists(countries_tsv):
    response = requests.get(countries_url)
    with open(countries_tsv, mode="wb") as fout:
        fout.write(response.content)
        
if not os.path.exists(aggregation_tsv):
    response = requests.get(aggregation_url)
    with open(aggregation_tsv, mode="wb") as fout:
        fout.write(response.content)

# %%
# load in canonical mapping of QID -> region name for labeling
with open(countries_tsv, 'r') as fin:
    assert next(fin).strip().split('\t') == countries_header
    for line in fin:
        row = line.strip().split("\t")
        qid = row[country_qid_idx]
        region_name = row[country_name_idx]
        QID_TO_REGION[qid] = region_name
print(f"Loaded {len(QID_TO_REGION)} QID-region pairs for matching against Wikidata -- e.g., Q31: {QID_TO_REGION['Q31']}")
    
with open(aggregation_tsv, 'r') as fin:
    assert next(fin).strip().split("\t") == aggregation_header
    for line in fin:
        row = line.strip().split("\t")
        qid_to = row[agg_qid_to_idx]
        qid_from = row[agg_qid_from_idx]
        if qid_to in QID_TO_REGION:
            # map new QID to valid country
            # e.g., QID for West Bank -> Palestine
            QID_TO_REGION[qid_from] = QID_TO_REGION[qid_to]
print(f"Now {len(QID_TO_REGION)} QID-region pairs after adding aggregations -- e.g., Q40362: {QID_TO_REGION['Q40362']}")
# Out:
# Loaded 250 QID-region pairs for matching against Wikidata -- e.g., Q31: Belgium
# Now 304 QID-region pairs after adding aggregations -- e.g., Q40362: Western Sahara

# %%
# Create table with QID -> Region mapping for making data in end result more readable
spark.createDataFrame(pd.DataFrame(QID_TO_REGION.items(), columns=['qid', 'region'])).createOrReplaceTempView('qid_to_region')
spark.sql("SELECT * FROM qid_to_region LIMIT 10").show(50, False)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +---------+-------------------+
# |qid      |region             |
# +---------+-------------------+
# |Q889     |Afghanistan        |
# |Q5689    |Åland              |
# |Q222     |Albania            |
# |Q262     |Algeria            |
# |Q16641   |American Samoa     |
# |Q228     |Andorra            |
# |Q916     |Angola             |
# |Q25228   |Anguilla           |
# |Q21590062|Antarctica         |
# |Q781     |Antigua and Barbuda|
# +---------+-------------------+

# %%
# value info in wikidata entity table (https://wikitech.wikimedia.org/wiki/Analytics/Data_Lake/Edits/Wikidata_entity)
# is a string as opposed to struct (because it has a variable schema)
# this UDF extracts the QID value (or null if doesn't exist)
def getWikidataValue(obj):
    try:
        d = json.loads(obj)
        return d.get('id')
    except Exception:
        return None
    
spark.udf.register('getWikidataValue', getWikidataValue, 'String')
# Out:
# <function __main__.getWikidataValue(obj)>

# %%
print("Wikidata snapshots:")
spark.sql('SHOW PARTITIONS wmf.wikidata_item_page_link').show(50, False)

print("\nMediawiki snapshots:")
spark.sql('SHOW PARTITIONS wmf_raw.mediawiki_project_namespace_map').show(50, False)
# Out:
# Wikidata snapshots:
# +-------------------+
# |partition          |
# +-------------------+
# |snapshot=2024-02-26|
# |snapshot=2024-03-04|
# |snapshot=2024-03-11|
# |snapshot=2024-03-18|
# |snapshot=2024-03-25|
# |snapshot=2024-04-01|
# |snapshot=2024-04-08|
# |snapshot=2024-04-15|
# +-------------------+
#
#
# Mediawiki snapshots:
# +------------------------+
# |partition               |
# +------------------------+
# |snapshot=2016-12_private|
# |snapshot=2017-07_private|
# |snapshot=2023-10        |
# |snapshot=2023-11        |
# |snapshot=2023-12        |
# |snapshot=2024-01        |
# |snapshot=2024-02        |
# |snapshot=2024-03        |
# +------------------------+

# %%
mediawiki_snapshot = '2024-03'
wikidata_snapshot = '2024-04-01'
prop_list = tuple(COUNTRY_PROPERTIES)
print(prop_list)
tablename = 'isaacj.qid_to_country'
# Out:
# ('P17', 'P19', 'P27', 'P131', 'P183', 'P361', 'P495', 'P1269', 'P1532', 'P3842')

# %%
create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {tablename} (
        qid              STRING  COMMENT 'Wikidata ID of item with at least one Wikipedia sitelink -- e.g., Q42',
        property         STRING  COMMENT 'Wikidata property (e.g., P625 for coordinates) from which country was derived',
        country          STRING  COMMENT 'Region name'
    )
    PARTITIONED BY (
        snapshot         STRING  COMMENT 'Wikidata snapshot processed'
    )
    """

print(create_table_query)
spark.sql(create_table_query)
# Out:
#     CREATE TABLE IF NOT EXISTS isaacj.qid_to_country (
#         qid              STRING  COMMENT 'Wikidata ID of item with at least one Wikipedia sitelink -- e.g., Q42',
#         property         STRING  COMMENT 'Wikidata property (e.g., P625 for coordinates) from which country was derived',
#         country          STRING  COMMENT 'Region name'
#     )
#     PARTITIONED BY (
#         snapshot         STRING  COMMENT 'Wikidata snapshot processed'
#     )
# 24/04/26 15:35:08 WARN ResolveSessionCatalog: A Hive serde table will be created as there is no table provider specified. You can set spark.sql.legacy.createHiveTableByDefault to false so that native data source table will be created instead.
# 24/04/26 15:35:08 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# DataFrame[]

# %%
"""
Full query is below that grabs country data from a set of ~10 properties
AND grabs country data based on an item's coordinates

Explanation of CTEs:
* relevant_wikis: get list of Wikipedia wiki_dbs (e.g., enwiki) so as to limit the
    the Wikidata items considered to just those with Wikipedia sitelinks
* relevant_qids: get set of Wikidata item IDs that have at least one Wikipedia sitelink
* exploded_statements: explode Wikidata entity data to one Wikidata claim per row
* relevant_statements: get all Wikidata claims that might have a country value
* INSERT: property countries into single table
"""

query = f"""
WITH relevant_wikis AS (
    SELECT
      DISTINCT(database_code) AS wiki_db
    FROM canonical_data.wikis
    WHERE
      database_group = 'wikipedia'
      AND status = 'open'
      AND visibility = 'public'
      AND editability = 'public'
),
relevant_qids AS (
    SELECT
      DISTINCT(item_id) AS item_id
    FROM wmf.wikidata_item_page_link wd
    INNER JOIN relevant_wikis db
      ON (wd.wiki_db = db.wiki_db)
    WHERE
      snapshot = '{wikidata_snapshot}'
      AND page_namespace = 0
),
exploded_statements AS (
    SELECT
      id AS item_id,
      explode(claims) AS claim
    FROM wmf.wikidata_entity w
    INNER JOIN relevant_qids q
      ON (w.id = q.item_id)
    WHERE
      w.snapshot = '{wikidata_snapshot}'
),
relevant_statements AS (
    SELECT
      item_id,
      claim.mainSnak.property AS property,
      getWikidataValue(claim.mainSnak.dataValue.value) as value
    FROM exploded_statements
    WHERE
      claim.mainSnak.property IN {prop_list}
)
INSERT OVERWRITE TABLE {tablename}
PARTITION(snapshot='{wikidata_snapshot}')
SELECT
  item_id,
  property,
  q.region AS country
FROM relevant_statements r
INNER JOIN qid_to_region q
  ON (r.value = q.qid)
"""

print(query)
result = spark.sql(query)
# Out:
# WITH relevant_wikis AS (
#     SELECT
#       DISTINCT(database_code) AS wiki_db
#     FROM canonical_data.wikis
#     WHERE
#       database_group = 'wikipedia'
#       AND status = 'open'
#       AND visibility = 'public'
#       AND editability = 'public'
# ),
# relevant_qids AS (
#     SELECT
#       DISTINCT(item_id) AS item_id
#     FROM wmf.wikidata_item_page_link wd
#     INNER JOIN relevant_wikis db
#       ON (wd.wiki_db = db.wiki_db)
#     WHERE
#       snapshot = '2024-04-01'
#       AND page_namespace = 0
# ),
# exploded_statements AS (
#     SELECT
#       id AS item_id,
#       explode(claims) AS claim
#     FROM wmf.wikidata_entity w
#     INNER JOIN relevant_qids q
#       ON (w.id = q.item_id)
#     WHERE
#       w.snapshot = '2024-04-01'
# ),
# relevant_statements AS (
#     SELECT
#       item_id,
#       claim.mainSnak.property AS property,
#       getWikidataValue(claim.mainSnak.dataValue.value) as value
#     FROM exploded_statements
#     WHERE
#       claim.mainSnak.property IN ('P17', 'P19', 'P27', 'P131', 'P183', 'P361', 'P495', 'P1269', 'P1532', 'P3842')
# )
# INSERT OVERWRITE TABLE isaacj.qid_to_country
# PARTITION(snapshot='2024-04-01')
# SELECT
#   item_id,
#   property,
#   q.region AS country
# FROM relevant_statements r
# INNER JOIN qid_to_region q
#   ON (r.value = q.qid)
# 24/04/26 15:43:58 ERROR YarnScheduler: Lost executor 41 on an-worker1138.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:58 WARN TaskSetManager: Lost task 16.0 in stage 6.0 (TID 982) (an-worker1138.eqiad.wmnet executor 41): ExecutorLostFailure (executor 41 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:58 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 41 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 7.0 in stage 6.0 (TID 973) (an-worker1138.eqiad.wmnet executor 41): ExecutorLostFailure (executor 41 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 25.0 in stage 6.0 (TID 991) (an-worker1138.eqiad.wmnet executor 41): ExecutorLostFailure (executor 41 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 34.0 in stage 6.0 (TID 1000) (an-worker1138.eqiad.wmnet executor 41): ExecutorLostFailure (executor 41 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 ERROR YarnScheduler: Lost executor 33 on an-worker1136.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 33 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 12.0 in stage 6.0 (TID 978) (an-worker1136.eqiad.wmnet executor 33): ExecutorLostFailure (executor 33 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 22.0 in stage 6.0 (TID 987) (an-worker1136.eqiad.wmnet executor 33): ExecutorLostFailure (executor 33 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 39.0 in stage 6.0 (TID 1005) (an-worker1136.eqiad.wmnet executor 33): ExecutorLostFailure (executor 33 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:43:59 WARN TaskSetManager: Lost task 30.0 in stage 6.0 (TID 996) (an-worker1136.eqiad.wmnet executor 33): ExecutorLostFailure (executor 33 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:01 ERROR YarnScheduler: Lost executor 17 on an-worker1123.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:01 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 17 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:01 WARN TaskSetManager: Lost task 28.0 in stage 6.0 (TID 994) (an-worker1123.eqiad.wmnet executor 17): ExecutorLostFailure (executor 17 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:01 WARN TaskSetManager: Lost task 19.0 in stage 6.0 (TID 985) (an-worker1123.eqiad.wmnet executor 17): ExecutorLostFailure (executor 17 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:01 WARN TaskSetManager: Lost task 10.0 in stage 6.0 (TID 976) (an-worker1123.eqiad.wmnet executor 17): ExecutorLostFailure (executor 17 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:01 WARN TaskSetManager: Lost task 37.0 in stage 6.0 (TID 1003) (an-worker1123.eqiad.wmnet executor 17): ExecutorLostFailure (executor 17 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:02 ERROR YarnScheduler: Lost executor 15 on an-worker1123.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:02 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 15 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:02 WARN TaskSetManager: Lost task 31.0 in stage 6.0 (TID 997) (an-worker1123.eqiad.wmnet executor 15): ExecutorLostFailure (executor 15 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:02 WARN TaskSetManager: Lost task 4.0 in stage 6.0 (TID 970) (an-worker1123.eqiad.wmnet executor 15): ExecutorLostFailure (executor 15 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:02 WARN TaskSetManager: Lost task 13.0 in stage 6.0 (TID 979) (an-worker1123.eqiad.wmnet executor 15): ExecutorLostFailure (executor 15 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:02 WARN TaskSetManager: Lost task 20.0 in stage 6.0 (TID 988) (an-worker1123.eqiad.wmnet executor 15): ExecutorLostFailure (executor 15 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 37 for reason Container killed by YARN for exceeding physical memory limits. 9.0 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 ERROR YarnScheduler: Lost executor 37 on an-worker1161.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 9.0 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 98.0 in stage 6.0 (TID 1064) (an-worker1161.eqiad.wmnet executor 37): ExecutorLostFailure (executor 37 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 9.0 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 121.0 in stage 6.0 (TID 1087) (an-worker1161.eqiad.wmnet executor 37): ExecutorLostFailure (executor 37 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 9.0 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 52.0 in stage 6.0 (TID 1018) (an-worker1161.eqiad.wmnet executor 37): ExecutorLostFailure (executor 37 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 9.0 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 75.0 in stage 6.0 (TID 1041) (an-worker1161.eqiad.wmnet executor 37): ExecutorLostFailure (executor 37 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 9.0 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 13 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 ERROR YarnScheduler: Lost executor 13 on an-worker1102.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 140.0 in stage 6.0 (TID 1106) (an-worker1102.eqiad.wmnet executor 13): ExecutorLostFailure (executor 13 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 71.0 in stage 6.0 (TID 1037) (an-worker1102.eqiad.wmnet executor 13): ExecutorLostFailure (executor 13 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 94.0 in stage 6.0 (TID 1060) (an-worker1102.eqiad.wmnet executor 13): ExecutorLostFailure (executor 13 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:03 WARN TaskSetManager: Lost task 117.0 in stage 6.0 (TID 1083) (an-worker1102.eqiad.wmnet executor 13): ExecutorLostFailure (executor 13 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:04 ERROR YarnScheduler: Lost executor 23 on an-worker1102.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:04 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 23 for reason Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:04 WARN TaskSetManager: Lost task 122.0 in stage 6.0 (TID 1088) (an-worker1102.eqiad.wmnet executor 23): ExecutorLostFailure (executor 23 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:04 WARN TaskSetManager: Lost task 53.0 in stage 6.0 (TID 1019) (an-worker1102.eqiad.wmnet executor 23): ExecutorLostFailure (executor 23 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:04 WARN TaskSetManager: Lost task 76.0 in stage 6.0 (TID 1042) (an-worker1102.eqiad.wmnet executor 23): ExecutorLostFailure (executor 23 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:04 WARN TaskSetManager: Lost task 99.0 in stage 6.0 (TID 1065) (an-worker1102.eqiad.wmnet executor 23): ExecutorLostFailure (executor 23 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:05 ERROR YarnScheduler: Lost executor 4 on an-worker1135.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:05 WARN TaskSetManager: Lost task 2.0 in stage 6.0 (TID 968) (an-worker1135.eqiad.wmnet executor 4): ExecutorLostFailure (executor 4 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:05 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 4 for reason Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:05 WARN TaskSetManager: Lost task 1.0 in stage 6.0 (TID 967) (an-worker1135.eqiad.wmnet executor 4): ExecutorLostFailure (executor 4 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:05 WARN TaskSetManager: Lost task 3.0 in stage 6.0 (TID 969) (an-worker1135.eqiad.wmnet executor 4): ExecutorLostFailure (executor 4 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:05 WARN TaskSetManager: Lost task 0.0 in stage 6.0 (TID 966) (an-worker1135.eqiad.wmnet executor 4): ExecutorLostFailure (executor 4 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:08 ERROR YarnScheduler: Lost executor 47 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:08 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 47 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:08 WARN TaskSetManager: Lost task 95.0 in stage 6.0 (TID 1061) (an-worker1150.eqiad.wmnet executor 47): ExecutorLostFailure (executor 47 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:08 WARN TaskSetManager: Lost task 118.0 in stage 6.0 (TID 1084) (an-worker1150.eqiad.wmnet executor 47): ExecutorLostFailure (executor 47 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:08 WARN TaskSetManager: Lost task 141.0 in stage 6.0 (TID 1107) (an-worker1150.eqiad.wmnet executor 47): ExecutorLostFailure (executor 47 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:08 WARN TaskSetManager: Lost task 72.0 in stage 6.0 (TID 1038) (an-worker1150.eqiad.wmnet executor 47): ExecutorLostFailure (executor 47 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 66 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 ERROR YarnScheduler: Lost executor 66 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 107.0 in stage 6.0 (TID 1073) (an-worker1150.eqiad.wmnet executor 66): ExecutorLostFailure (executor 66 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 64 for reason Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 130.0 in stage 6.0 (TID 1096) (an-worker1150.eqiad.wmnet executor 66): ExecutorLostFailure (executor 66 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 61.0 in stage 6.0 (TID 1027) (an-worker1150.eqiad.wmnet executor 66): ExecutorLostFailure (executor 66 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 84.0 in stage 6.0 (TID 1050) (an-worker1150.eqiad.wmnet executor 66): ExecutorLostFailure (executor 66 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 59 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 ERROR YarnScheduler: Lost executor 64 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 92.0 in stage 6.0 (TID 1058) (an-worker1150.eqiad.wmnet executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 115.0 in stage 6.0 (TID 1081) (an-worker1150.eqiad.wmnet executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 50 for reason Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 138.0 in stage 6.0 (TID 1104) (an-worker1150.eqiad.wmnet executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 69.0 in stage 6.0 (TID 1035) (an-worker1150.eqiad.wmnet executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 ERROR YarnScheduler: Lost executor 59 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 116.0 in stage 6.0 (TID 1082) (an-worker1150.eqiad.wmnet executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 139.0 in stage 6.0 (TID 1105) (an-worker1150.eqiad.wmnet executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 70.0 in stage 6.0 (TID 1036) (an-worker1150.eqiad.wmnet executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 93.0 in stage 6.0 (TID 1059) (an-worker1150.eqiad.wmnet executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 ERROR YarnScheduler: Lost executor 50 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 68.0 in stage 6.0 (TID 1034) (an-worker1150.eqiad.wmnet executor 50): ExecutorLostFailure (executor 50 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 91.0 in stage 6.0 (TID 1057) (an-worker1150.eqiad.wmnet executor 50): ExecutorLostFailure (executor 50 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 114.0 in stage 6.0 (TID 1080) (an-worker1150.eqiad.wmnet executor 50): ExecutorLostFailure (executor 50 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:09 WARN TaskSetManager: Lost task 137.0 in stage 6.0 (TID 1103) (an-worker1150.eqiad.wmnet executor 50): ExecutorLostFailure (executor 50 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:12 ERROR YarnScheduler: Lost executor 65 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:12 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 65 for reason Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:12 WARN TaskSetManager: Lost task 113.0 in stage 6.0 (TID 1079) (an-worker1150.eqiad.wmnet executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:12 WARN TaskSetManager: Lost task 136.0 in stage 6.0 (TID 1102) (an-worker1150.eqiad.wmnet executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:12 WARN TaskSetManager: Lost task 67.0 in stage 6.0 (TID 1033) (an-worker1150.eqiad.wmnet executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:44:12 WARN TaskSetManager: Lost task 90.0 in stage 6.0 (TID 1056) (an-worker1150.eqiad.wmnet executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding physical memory limits. 8.9 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:45:10 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 48 for reason Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:45:10 ERROR YarnScheduler: Lost executor 48 on an-worker1150.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.

# %%
# check output (this was before coordinate data was added)
spark.sql(f"""
WITH enwiki_qids AS (
    SELECT
      DISTINCT(item_id)
    FROM wmf.wikidata_item_page_link
    WHERE
      snapshot = "{wikidata_snapshot}"
      AND wiki_db = "enwiki"
)
SELECT
  country,
  COUNT(DISTINCT(qid)) AS num_qids,
  COUNT(1) AS num_rows
FROM {tablename} all
INNER JOIN enwiki_qids e
  ON (all.qid = e.item_id)
WHERE
  snapshot = "{wikidata_snapshot}"
GROUP BY
  country
ORDER BY
  num_qids DESC
""").show(500, False)
# Out:
# [Stage 12:=====================================================>(252 + 4) / 256]
# +---------------------------------------------+--------+--------+
# |country                                      |num_qids|num_rows|
# +---------------------------------------------+--------+--------+
# |United States                                |1131578 |1169109 |
# |United Kingdom                               |376172  |398002  |
# |France                                       |164963  |172442  |
# |India                                        |158797  |162277  |
# |Canada                                       |152921  |156768  |
# |Australia                                    |128825  |132925  |
# |Germany                                      |125051  |133869  |
# |Japan                                        |98163   |102044  |
# |Poland                                       |85451   |87406   |
# |Italy                                        |84769   |88790   |
# |Russia                                       |72605   |78628   |
# |Iran                                         |69848   |70733   |
# |Spain                                        |69721   |72601   |
# |China                                        |57097   |58786   |
# |Brazil                                       |47234   |56046   |
# |Sweden                                       |43346   |46753   |
# |Norway                                       |41746   |45000   |
# |New Zealand                                  |41264   |43853   |
# |Turkey                                       |40676   |41940   |
# |Mexico                                       |33351   |34738   |
# |Ireland                                      |30843   |32561   |
# |Switzerland                                  |29726   |31578   |
# |Romania                                      |28513   |30028   |
# |Argentina                                    |26811   |28604   |
# |South Korea                                  |25081   |27856   |
# |South Africa                                 |24925   |26416   |
# |Belgium                                      |24768   |28341   |
# |Austria                                      |24362   |25914   |
# |Philippines                                  |22940   |23493   |
# |Denmark                                      |22365   |23348   |
# |Pakistan                                     |21599   |22318   |
# |Finland                                      |21548   |24937   |
# |Netherlands                                  |21121   |21825   |
# |Ukraine                                      |20909   |24474   |
# |Hungary                                      |20902   |22358   |
# |Greece                                       |20043   |20975   |
# |Czech Republic                               |19291   |20612   |
# |Israel                                       |18253   |19656   |
# |Portugal                                     |16806   |18162   |
# |Indonesia                                    |16322   |17490   |
# |Nigeria                                      |15664   |17564   |
# |Serbia                                       |15040   |15862   |
# |Estonia                                      |14317   |14908   |
# |Malaysia                                     |14133   |14613   |
# |Antarctica                                   |14040   |14045   |
# |Peru                                         |12737   |13299   |
# |Croatia                                      |12613   |13276   |
# |Chile                                        |12580   |13530   |
# |Thailand                                     |12514   |13108   |
# |Bangladesh                                   |12409   |12775   |
# |Bulgaria                                     |12400   |13949   |
# |Slovenia                                     |12309   |13097   |
# |Colombia                                     |10509   |11256   |
# |Sri Lanka                                    |10452   |11115   |
# |Taiwan                                       |10169   |10580   |
# |Azerbaijan                                   |9890    |10515   |
# |Nepal                                        |9480    |9728    |
# |Slovakia                                     |9429    |10107   |
# |Bosnia and Herzegovina                       |9092    |9811    |
# |Egypt                                        |8832    |9573    |
# |Ghana                                        |8275    |9238    |
# |Hong Kong                                    |8096    |8556    |
# |Vietnam                                      |7730    |8084    |
# |Algeria                                      |7645    |8101    |
# |Venezuela                                    |7614    |7982    |
# |Kenya                                        |7102    |7642    |
# |Singapore                                    |6850    |8068    |
# |Albania                                      |6693    |7229    |
# |Lithuania                                    |6507    |7143    |
# |Morocco                                      |6324    |6870    |
# |Cuba                                         |6151    |6579    |
# |Latvia                                       |6110    |6804    |
# |Myanmar                                      |5955    |6125    |
# |Uruguay                                      |5919    |6458    |
# |Belarus                                      |5539    |6817    |
# |Iceland                                      |5345    |6109    |
# |Syria                                        |5320    |5504    |
# |Bolivia                                      |4964    |5261    |
# |Kazakhstan                                   |4931    |5664    |
# |Armenia                                      |4896    |5321    |
# |Saudi Arabia                                 |4804    |5711    |
# |Iraq                                         |4769    |5079    |
# |Georgia                                      |4729    |5274    |
# |Afghanistan                                  |4584    |4855    |
# |Lebanon                                      |4584    |4846    |
# |Tunisia                                      |4565    |4967    |
# |Uganda                                       |4477    |5154    |
# |Ecuador                                      |4268    |4558    |
# |Tanzania                                     |4234    |4449    |
# |North Macedonia                              |3933    |4375    |
# |Burkina Faso                                 |3863    |4006    |
# |Madagascar                                   |3838    |3977    |
# |Jamaica                                      |3835    |4299    |
# |Ethiopia                                     |3765    |4007    |
# |Luxembourg                                   |3686    |4127    |
# |Moldova                                      |3570    |3968    |
# |Democratic Republic of the Congo             |3519    |3702    |
# |Costa Rica                                   |3456    |3758    |
# |United Arab Emirates                         |3401    |3902    |
# |Cameroon                                     |3390    |3853    |
# |North Korea                                  |3386    |3754    |
# |Dominican Republic                           |3344    |3525    |
# |Papua New Guinea                             |3176    |3347    |
# |Cyprus                                       |3158    |3452    |
# |Ivory Coast                                  |3143    |3490    |
# |Uzbekistan                                   |3104    |3400    |
# |Malta                                        |3067    |3437    |
# |Zimbabwe                                     |3059    |3359    |
# |Paraguay                                     |3046    |3446    |
# |Yemen                                        |3019    |3151    |
# |Montenegro                                   |2925    |3194    |
# |Senegal                                      |2827    |3156    |
# |Panama                                       |2764    |2984    |
# |Mali                                         |2679    |2862    |
# |Guatemala                                    |2656    |2836    |
# |Puerto Rico                                  |2631    |2747    |
# |Angola                                       |2517    |2674    |
# |Cambodia                                     |2437    |2554    |
# |Palestine                                    |2401    |2577    |
# |Kyrgyzstan                                   |2328    |2464    |
# |Honduras                                     |2325    |2519    |
# |Haiti                                        |2292    |2526    |
# |Mongolia                                     |2266    |2473    |
# |Namibia                                      |2252    |2427    |
# |Jordan                                       |2167    |2283    |
# |Somalia                                      |2134    |2349    |
# |Qatar                                        |2100    |2447    |
# |El Salvador                                  |2084    |2269    |
# |Trinidad and Tobago                          |2057    |2341    |
# |Zambia                                       |1954    |2186    |
# |Fiji                                         |1869    |2199    |
# |Libya                                        |1779    |1896    |
# |Benin                                        |1767    |1849    |
# |Sudan                                        |1744    |1879    |
# |Kosovo                                       |1609    |1708    |
# |Tajikistan                                   |1540    |1636    |
# |Greenland                                    |1504    |1530    |
# |Togo                                         |1500    |1601    |
# |Guinea                                       |1490    |1603    |
# |Mozambique                                   |1465    |1548    |
# |Nicaragua                                    |1458    |1540    |
# |Kuwait                                       |1445    |1651    |
# |Botswana                                     |1416    |1534    |
# |Cape Verde                                   |1379    |1510    |
# |Bahrain                                      |1314    |1496    |
# |Sierra Leone                                 |1306    |1378    |
# |Laos                                         |1297    |1391    |
# |Republic of the Congo                        |1289    |1414    |
# |Chad                                         |1270    |1343    |
# |Niger                                        |1245    |1312    |
# |Maldives                                     |1241    |1331    |
# |Rwanda                                       |1231    |1338    |
# |Liberia                                      |1223    |1345    |
# |Bhutan                                       |1212    |1304    |
# |Barbados                                     |1202    |1331    |
# |Suriname                                     |1200    |1307    |
# |Guyana                                       |1193    |1298    |
# |Oman                                         |1154    |1269    |
# |Monaco                                       |1139    |1270    |
# |Gabon                                        |1079    |1163    |
# |Turkmenistan                                 |1068    |1179    |
# |Malawi                                       |1056    |1136    |
# |Bahamas                                      |1023    |1140    |
# |San Marino                                   |1012    |1247    |
# |Mauritania                                   |1009    |1073    |
# |Brunei                                       |985     |1071    |
# |Central African Republic                     |983     |1031    |
# |Belize                                       |982     |1041    |
# |Andorra                                      |979     |1119    |
# |Liechtenstein                                |976     |1138    |
# |Samoa                                        |964     |1075    |
# |Tonga                                        |964     |1104    |
# |Faroe Islands                                |964     |1059    |
# |Gambia                                       |962     |1069    |
# |Mauritius                                    |952     |1111    |
# |South Sudan                                  |925     |978     |
# |East Timor                                   |921     |979     |
# |Burundi                                      |859     |938     |
# |Eritrea                                      |839     |909     |
# |Solomon Islands                              |810     |885     |
# |Vanuatu                                      |776     |879     |
# |South Georgia and the South Sandwich Islands |769     |820     |
# |Antigua and Barbuda                          |761     |877     |
# |Bermuda                                      |736     |1111    |
# |Lesotho                                      |692     |777     |
# |Isle of Man                                  |689     |902     |
# |Guinea-Bissau                                |681     |763     |
# |Equatorial Guinea                            |665     |766     |
# |Gibraltar                                    |654     |743     |
# |Seychelles                                   |610     |715     |
# |Grenada                                      |597     |675     |
# |Dominica                                     |593     |651     |
# |Comoros                                      |591     |639     |
# |Eswatini                                     |585     |649     |
# |United States Virgin Islands                 |575     |610     |
# |Saint Lucia                                  |563     |622     |
# |Djibouti                                     |533     |569     |
# |São Tomé and Príncipe                        |531     |577     |
# |Macao                                        |499     |535     |
# |Vatican City                                 |494     |551     |
# |New Caledonia                                |486     |496     |
# |Jersey                                       |456     |500     |
# |Cook Islands                                 |451     |493     |
# |Aruba                                        |420     |466     |
# |Tuvalu                                       |416     |442     |
# |Saint Vincent and the Grenadines             |412     |446     |
# |Saint Kitts and Nevis                        |409     |443     |
# |Federated States of Micronesia               |406     |424     |
# |Kiribati                                     |399     |422     |
# |Curaçao                                      |383     |408     |
# |Palau                                        |377     |408     |
# |Guam                                         |374     |400     |
# |Guernsey                                     |346     |380     |
# |Nauru                                        |332     |391     |
# |Marshall Islands                             |322     |378     |
# |Cayman Islands                               |296     |329     |
# |Guadeloupe                                   |251     |256     |
# |Falkland Islands                             |248     |316     |
# |British Virgin Islands                       |241     |284     |
# |American Samoa                               |225     |248     |
# |French Polynesia                             |224     |226     |
# |Réunion                                      |216     |219     |
# |Martinique                                   |213     |220     |
# |Western Sahara                               |186     |217     |
# |Niue                                         |176     |189     |
# |Anguilla                                     |142     |166     |
# |Montserrat                                   |140     |166     |
# |Turks and Caicos Islands                     |138     |155     |
# |French Guiana                                |123     |127     |
# |Sint Maarten                                 |103     |109     |
# |Northern Mariana Islands                     |101     |114     |
# |Saint Helena, Ascension, and Tristan da Cunha|90      |103     |
# |Bonaire, Sint Eustatius, and Saba            |82      |84      |
# |Mayotte                                      |79      |82      |
# |Saint Barthélemy                             |64      |64      |
# |Wallis and Futuna                            |63      |66      |
# |Pitcairn Islands                             |61      |72      |
# |Norfolk Island                               |60      |62      |
# |Tokelau                                      |58      |63      |
# |Åland                                        |48      |50      |
# |French Southern and Antarctic Lands          |48      |49      |
# |Saint Martin                                 |43      |43      |
# |United States Minor Outlying Islands         |39      |40      |
# |Saint Pierre and Miquelon                    |34      |34      |
# |Bouvet Island                                |31      |31      |
# |Christmas Island                             |31      |33      |
# |British Indian Ocean Territory               |24      |24      |
# |Cocos (Keeling) Islands                      |20      |25      |
# +---------------------------------------------+--------+--------+
# 24/04/26 15:45:53 WARN YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 32 for reason Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# 24/04/26 15:45:53 ERROR YarnScheduler: Lost executor 32 on an-worker1136.eqiad.wmnet: Container killed by YARN for exceeding physical memory limits. 8.8 GB of 8.8 GB physical memory used. Consider boosting spark.executor.memoryOverhead.
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 57590)
# Traceback (most recent call last):
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/site-packages/pyspark/accumulators.py", line 262, in handle
#     poll(accum_updates)
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/site-packages/pyspark/accumulators.py", line 235, in poll
#     if func():
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/site-packages/pyspark/accumulators.py", line 239, in accum_updates
#     num_updates = read_int(self.rfile)
#   File "/home/isaacj/.conda/envs/2024-01-17T14.42.46_isaacj/lib/python3.10/site-packages/pyspark/serializers.py", line 564, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
